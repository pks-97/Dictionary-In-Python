# %%
d = {"Pratyush":5,"Sahoo":2}

# %%
d["Pratyush"]
# Out:
# 5

# %%
import json

# %%
data = json.load(open("data.json"))

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {u'fawn': [u'A young deer.', u'To act in a very submissive manner.'],
#  u'unattackable': [u'Immune to attack; incapable of being tampered with.'],
#  u'unsupportable': [u'That cannot be borne or endured.'],
#  u'homomorphism': [u'A mapping between mathematical structures of the same type.'],
#  u'Daga': [u'A language of Papua New Guinea.'],
#  u'nunnery': [u'The habitation and workplace of a community of monks or nuns.',
#   u'A convent for women.'],
#  u'International Court of Justice': [u'Judicial arm of the United Nations. It has jurisdiction to give advisory opinions on matters of law and treaty construction when requested by the General Assembly, Security Council or any other international agency authorised by the General Assembly to petition for such opinion. It has jurisdiction, also, to settle legal disputes between nations when voluntarily submitted to it.\\n(Source: BLACK)'],
# ...

# %%
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data["rain"]
# Out:
# [u'Precipitation in the form of liquid water drops with diameters greater than 0.5 millimetres.',
#  u'To fall from the clouds in drops of water.']

# %%
import json

data = json.load(open("data.json"))



def translate(word):
    return data[word]

word = input("Enter Word: ")

print(translate(word))
# Out:
# Enter Word: pot
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-fb34e86a6e45> in <module>()
#       8     return data[word]
#       9
# ---> 10 word = input("Enter Word: ")
#      11
#      12 print(translate(word))
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
#     166         getpass.getpass = self.getpass
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <module>()
#
# NameError: name 'pot' is not defined

# %%
import json

data = json.load(open("data.json"))

def translate(word):
    return data[word]


word = str(input("Enter word:"))
print(type(word))
# Out:
# Enter word:rain
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-785ee3b0f50e> in <module>()
#       7
#       8
# ----> 9 word = str(input("Enter word:"))
#      10 print(type(word))
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
#     166         getpass.getpass = self.getpass
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <module>()
#
# NameError: name 'rain' is not defined

# %%
word = Input("enter")
print(type(word))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-83da7031e0c5> in <module>()
# ----> 1 word = Input("enter")
#       2 print(type(word))
#
# NameError: name 'Input' is not defined

# %%
name = input("What's your name? ")
print("Nice to meet you " + name + "!")
age = input("Your age? ")
print("So, you are already " + str(age) + " years old, " + name + "!")
# Out:
# What's your name? pratyush
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-93e4bf90ac65> in <module>()
# ----> 1 name = input("What's your name? ")
#       2 print("Nice to meet you " + name + "!")
#       3 age = input("Your age? ")
#       4 print("So, you are already " + str(age) + " years old, " + name + "!")
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     162             self._sys_eval_input = builtin_mod.input
#     163             builtin_mod.raw_input = self.raw_input
# --> 164             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     165         self._save_getpass = getpass.getpass
#     166         getpass.getpass = self.getpass
#
# C:\Users\Pratyush\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <module>()
#
# NameError: name 'pratyush' is not defined

# %%
data
# Out:
# {u'fawn': [u'A young deer.', u'To act in a very submissive manner.'],
#  u'unattackable': [u'Immune to attack; incapable of being tampered with.'],
#  u'unsupportable': [u'That cannot be borne or endured.'],
#  u'homomorphism': [u'A mapping between mathematical structures of the same type.'],
#  u'Daga': [u'A language of Papua New Guinea.'],
#  u'nunnery': [u'The habitation and workplace of a community of monks or nuns.',
#   u'A convent for women.'],
#  u'International Court of Justice': [u'Judicial arm of the United Nations. It has jurisdiction to give advisory opinions on matters of law and treaty construction when requested by the General Assembly, Security Council or any other international agency authorised by the General Assembly to petition for such opinion. It has jurisdiction, also, to settle legal disputes between nations when voluntarily submitted to it.\\n(Source: BLACK)'],
# ...

# %%
data["adasdasd"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-a50d843de35f> in <module>()
# ----> 1 data["adasdasd"]
#
# KeyError: 'adasdasd'

# %%
"rain" in data
# Out:
# True

# %%
"pratyush" in data
# Out:
# False

# %%
"Pratyush".lower()
# Out:
# 'pratyush'

# %%
import difflib

# %%
from difflib import SequenceMatcher
SequenceMatcher(None, "rainn", "rain").ratio()
# Out:
# 0.8888888888888888

# %%
for i in data:
    print(i)
# Out:
# fawn
# unattackable
# unsupportable
# homomorphism
# Daga
# nunnery
# International Court of Justice
# status of development
# Lower Kartli
# woods
# art of cooking
# hanging
# radiation exposure
# spidery
# Issoirien
# Kyango
# Garaw-Gino
# arachnophobia
# black hole
# PacNW
# scold
# Ticinese Spoken
# Celitberian
# hallucinate
# Eure
# alphabetic
# Logba
# rumbustious
# bioclimatology
# Kaqchiquel
# Kapriman
# rheumatoid arthritis
# equatorial climate
# stipulate
# pigment
# active sensor
# open cluster
# Adjukru
# Brigasc Spoken
# Shuli
# medicament
# Portuguese Spoken
# ravishment
# fractal
# duck-billed platypus
# Loei
# risk assessment
# wooden
# Sach
# economy class
# salination
# circuitry
# crotch
# Teso Cluster
# forgather
# town planning
# inevitably
# double chin
# Todrah-Monom Cluster
# emergency shelter
# reengineering
# Sirmauri Spoken
# prosody
# Anykh
# inanimate
# efficaciousness
# myriagram
# semicircular
# graviception
# cooking
# BIRT
# Mi-Marva
# Asumboa
# ...

# %%
maxi = 0
j = None
for i in data:
    t = SequenceMatcher(None, "batt", i).ratio()
#     print(data[i])
    if t > maxi:
        j = i
        maxi = t
# print(maxi) 
print(j)
# Out:
# att

# %%
SequenceMatcher(None,"rainn","rain").ratio()
# Out:
# 0.8888888888888888

# %%
data["batik"]
# Out:
# [u'A fabric dyeing technique in which the pattern is first drawn with melted beeswax onto the cloth with a metal tool.']

# %%
data["att"]
# Out:
# [u'A subdivision of the Laotian kip, 100 att=1 kip.']

# %%
from difflib import get_close_matches
print(get_close_matches("bati",["bat","att","batik"],1))[0]
# Out:
# batik

# %%
data.keys()
# Out:
# [u'fawn',
#  u'unattackable',
#  u'unsupportable',
#  u'homomorphism',
#  u'Daga',
#  u'nunnery',
#  u'International Court of Justice',
#  u'status of development',
#  u'Lower Kartli',
#  u'woods',
#  u'art of cooking',
#  u'hanging',
#  u'radiation exposure',
#  u'spidery',
#  u'Issoirien',
#  u'Kyango',
#  u'Garaw-Gino',
#  u'arachnophobia',
#  u'black hole',
#  u'PacNW',
#  u'scold',
#  u'Ticinese Spoken',
#  u'Celitberian',
#  u'hallucinate',
#  u'Eure',
#  u'alphabetic',
#  u'Logba',
#  u'rumbustious',
#  u'bioclimatology',
#  u'Kaqchiquel',
#  u'Kapriman',
#  u'rheumatoid arthritis',
#  u'equatorial climate',
#  u'stipulate',
#  u'pigment',
#  u'active sensor',
#  u'open cluster',
#  u'Adjukru',
#  u'Brigasc Spoken',
#  u'Shuli',
#  u'medicament',
#  u'Portuguese Spoken',
#  u'ravishment',
#  u'fractal',
#  u'duck-billed platypus',
#  u'Loei',
#  u'risk assessment',
#  u'wooden',
#  u'Sach',
#  u'economy class',
#  u'salination',
#  u'circuitry',
#  u'crotch',
# ...

# %%
get_close_matches("rain",data.keys(),n=5)
# Out:
# [u'rain', u'train', u'rainy', u'grain', u'drain']

# %%
data["rant"]
# Out:
# [u'A declamation written, or more often oral, where emotionality supersedes rationality. Its purpose is a call to action, often identifying a target for ire and a path to resolution. Due to the pejorative connotation of the term it is a descriptor that is often subjective, most often applied to messages disagreed with.']
